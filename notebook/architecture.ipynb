# %%
import matplotlib.pyplot as plt

def plot_neural_network(layers):
    # Initialize figure
    fig, ax = plt.subplots(figsize=(6, 8))

    # Define colors for each layer
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightsalmon']

    # Plot layers
    for i, layer in enumerate(layers):
        ax.text(0.5, 1 - i * 0.15, layer, va='center', ha='center', fontsize=12, transform=ax.transAxes,
                bbox=dict(facecolor=colors[i], alpha=0.5, boxstyle='round,pad=0.3'))

    # Remove axes
    ax.axis('off')

    # Title
    ax.set_title('Neural Network Architecture', fontsize=14)

    # Adjust layout
    plt.tight_layout()

    # Show plot
    plt.show()

# Define layers of the neural network
layers = [
    'Input\n(shape=(SEQ_LENGTH,))',
    'Dense\n(256, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(128, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(64, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(32, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(num_output, sigmoid)'
]

# Plot the neural network architecture
plot_neural_network(layers)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w8/b_cflrn97k9c15rcrn5t8mmr0000gn/T/ipykernel_22193/1301476611.py in <cell line: 0>()
#      40
#      41 # Plot the neural network architecture
# ---> 42 plot_neural_network(layers)
#
# /var/folders/w8/b_cflrn97k9c15rcrn5t8mmr0000gn/T/ipykernel_22193/1301476611.py in plot_neural_network(layers)
#      11     for i, layer in enumerate(layers):
#      12         ax.text(0.5, 1 - i * 0.15, layer, va='center', ha='center', fontsize=12, transform=ax.transAxes,
# ---> 13                 bbox=dict(facecolor=colors[i], alpha=0.5, boxstyle='round,pad=0.3'))
#      14
#      15     # Remove axes
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt

def plot_neural_network(layers):
    # Initialize figure
    fig, ax = plt.subplots(figsize=(8, 6))

    # Define colors for each layer
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightsalmon']

    # Plot layers
    for i, layer in enumerate(layers):
        ax.text(0.5, 1 - i * 0.15, layer, va='center', ha='center', fontsize=12, transform=ax.transAxes,
                bbox=dict(facecolor=colors[i % len(colors)], alpha=0.5, boxstyle='round,pad=0.3'))

    # Remove axes
    ax.axis('off')

    # Title
    #ax.set_title('Neural Network Architecture', fontsize=14)

    # Adjust layout
    plt.tight_layout()
    plt.savefig('bin_model_pygenomics')

    # Show plot
    plt.show()

# Define layers of the neural network
layers = [
    'Input\n(shape=(FEATURE_LENGTH,))',
    'Dense\n(256, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(128, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(64, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(32, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(num_output=1, sigmoid)'
]

# Plot the neural network architecture
plot_neural_network(layers)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrow

def plot_neural_network(layers):
    # Initialize figure
    fig, ax = plt.subplots(figsize=(8, 6))

    # Define colors for each layer
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightsalmon']

    # Plot layers and arrows
    x_start, y_start = 0.5, 1
    x_end, y_end = 0.5, 1 - (len(layers) - 1) * 0.15

    for i, layer in enumerate(layers):
        # Plot layer block
        ax.text(x_start, y_start - i * 0.15, layer, va='center', ha='center', fontsize=12, transform=ax.transAxes,
                bbox=dict(facecolor=colors[i % len(colors)], alpha=0.5, boxstyle='round,pad=0.3'))

        # Plot arrow (if not the first layer)
        if i > 0:
            arrow = FancyArrow(x_start, y_start - (i - 0.5) * 0.15, x_end - x_start, (y_end - y_start) / (len(layers) - 1),
                               transform=ax.transAxes, fc='gray', ec='gray', head_width=0.03, head_length=0.03, lw=1,
                               linestyle=':')
            ax.add_patch(arrow)

    # Remove axes
    ax.axis('off')

    # Title

    # Adjust layout
    plt.tight_layout()

    # Show plot
    plt.savefig('bin_model_pygenomics')
    plt.show()

# Define layers of the neural network
layers = [
    'Input\n(shape=(SEQ_LENGTH,))',
    'Dense\n(256, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(128, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(64, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(32, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(num_output, sigmoid)'
]

# Plot the neural network architecture
plot_neural_network(layers)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrow

def plot_neural_network(layers):
    # Initialize figure
    fig, ax = plt.subplots(figsize=(8, 6))

    # Define colors for each layer
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightsalmon']

    # Plot layers and arrows
    x_start, y_start = 0.5, 1
    x_end, y_end = 0.5, 1 - len(layers) * 0.15

    # Define arrow properties
    arrow_props = dict(fc='gray', ec='gray', head_width=0.03, head_length=0.03, lw=1, linestyle=':')

    for i, layer in enumerate(layers):
        # Plot layer block
        ax.text(x_start, y_start - i * 0.15, layer, va='center', ha='center', fontsize=12, transform=ax.transAxes,
                bbox=dict(facecolor=colors[i % len(colors)], alpha=0.5, boxstyle='round,pad=0.3'))

        # Plot arrow (if not the last layer)
        if i < len(layers) - 1:
            arrow = FancyArrow(x_start, y_start - (i + 0.5) * 0.15, x_end - x_start, -0.08,
                               transform=ax.transAxes, **arrow_props)
            ax.add_patch(arrow)

    # Remove axes
    ax.axis('off')

    # Title
    ax.set_title('Neural Network Architecture', fontsize=14)

    # Adjust layout
    plt.tight_layout()

    # Show plot
    plt.show()

# Define layers of the neural network
layers = [
    'Input\n(shape=(SEQ_LENGTH,))',
    'Dense\n(256, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(128, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(64, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(32, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(num_output, sigmoid)'
]

# Plot the neural network architecture
plot_neural_network(layers)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrow

def plot_neural_network(layers):
    # Initialize figure
    fig, ax = plt.subplots(figsize=(8, 6))

    # Define colors for each layer
    colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightyellow', 'lightsalmon']

    # Plot layers and arrows
    x_start, y_start = 0.5, 1
    x_end, y_end = 0.5, 1 - (len(layers) - 30) * 0.15

    for i, layer in enumerate(layers):
        # Plot layer block
        ax.text(x_start, y_start - i * 0.15, layer, va='center', ha='center', fontsize=12, transform=ax.transAxes,
                bbox=dict(facecolor=colors[i % len(colors)], alpha=0.5, boxstyle='round,pad=0.3'))

        # Plot arrow (if not the first layer)
        arrow = FancyArrow(x_start, y_start - (i - 0.5) * 0.15, x_end - x_start, -0.12,
                           transform=ax.transAxes, fc='gray', ec='gray', head_width=0.03, head_length=0.03, lw=1,
                           linestyle=':')
        ax.add_patch(arrow)

    # Remove axes
    ax.axis('off')

    # Title

    
    # Adjust layout
    plt.tight_layout()

    # Show plot
    plt.show()

# Define layers of the neural network
layers = [
    'Input\n(shape=(SEQ_LENGTH,))',
    'Dense\n(256, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(128, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(64, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(32, relu)',
    'Dropout\n(rate=0.1)',
    'Dense\n(num_output, sigmoid)'
]

# Plot the neural network architecture
plot_neural_network(layers)
