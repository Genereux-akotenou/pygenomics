# %% [markdown]
# * **Setup**

# %%
import sys, os
current_directory = os.getcwd()
root_directory = os.path.abspath(os.path.join(current_directory, os.pardir))
sys.path.append(root_directory)

# %% [markdown]
# * **Import utils**

# %%
from pretrained.predictor import SingleKModel, MultiKModel, OneTestKModel, BatchSingleKModel
import metrics
# Out:
# [MacBook-Pro-de-Genereux.local:13837] shmem: mmap: an error occurred while determining whether or not /var/folders/w8/b_cflrn97k9c15rcrn5t8mmr0000gn/T//ompi.MacBook-Pro-de-Genereux.501/jf.0/2081619968/sm_segment.MacBook-Pro-de-Genereux.501.7c130000.0 could be created.

# %% [markdown]
# * **Predict**
#
# 1- Using single K Model

# %%
kmodel = BatchSingleKModel(kmer_size=5, batch_size=2000)
kmodel.set_load_config("../data/testset-full/k5/testset.csv", format="csv", type='kmer_file')
genboard = kmodel.predict()
# Out:
# Batch Predictions: 33it [39:10, 71.24s/it]

# %%
metrics.plot_testset(true_label_df_path="../data/testset-full/k5/true_labels.csv", class_mapping_df_path="../data/testset-full/k5/class_mapping.json")

# %%
genboard.display()
# Out:
# Tab(children=(VBox(children=(HBox(children=(VBox(children=(FloatSlider(value=0.5, continuous_update=False, des…

# %% [markdown]
# <!--<img src="data:image/png;base64,..."/>

# %%
genboard.prediction.shape
# Out:
# (64091, 58)

# %% [markdown]
# * **Confusion report for validation**

# %%
import json
import pandas as pd

true_label = pd.read_csv('../data/testset-full/k5/true_labels.csv')['true_label'].values
with open('../data/testset-full/k5/class_mapping.json', 'r') as json_file:
    class_mapping = json.load(json_file)
class_mapping['Unknown'] = 0

# %%
genboard.show_eval_metric(
    true_label=true_label,
    class_mapping_rules=class_mapping,
    voting_method="Two-Stage Voting",
    voting_threshold=0.5,
    binary_class_threshold=0.5,
    components=['confusion_matrix', 'general_accuracy', 'accuracy_per_family']
)
# Out:
# <h3 style='display: flex; justify-content: space-between;'>                <span style='width: 100%;'>Overall Accuracy</span> <span style='padding: 0.3em;background-color: #1f77b4;color: #fff;font-size: 0.85em;'>kmer_size=5</span></h3>                <table style='width:100%; border-collapse: collapse; border: 1px solid black;'>                <tr><th style='text-align: left;'>Score</th><td>0.91</td></tr></table><h3>Accuracy per Gene Family</h3><div style=''>                <table style='width:calc(50% - 1em); float:left; border-collapse: collapse; border: 1px solid black; margin-left: 0.5em;'>                <tr><th>Gene Family</th><th>Accuracy</th><th>Precision</th><th>Recall</th><th>F1 Score</th></tr><tr><td>AP2</td><td><b>0.99</b></td><td>0.51</td><td>0.95</td><td>0.67</td></tr><tr><td>ARR-B</td><td><b>0.99</b></td><td>0.53</td><td>0.98</td><td>0.68</td></tr><tr><td>BBR-BPC</td><td><b>1.00</b></td><td>1.00</td><td>0.98</td><td>0.99</td></tr><tr><td>C2H2</td><td><b>0.99</b></td><td>1.00</td><td>0.84</td><td>0.91</td></tr><tr><td>CAMTA</td><td><b>1.00</b></td><td>1.00</td><td>1
td><td>1.00</td></tr><tr><td>C3H</td><td><b>1.00</b></td><td>1.00</td><td>0.88</td><td>0.93</td></tr><tr><td>CO-like</td><td><b>1.00</b></td><td>0.99</td><td>1.00</td><td>0.99</td></tr><tr><td>DBB</td><td><b>1.00</b></td><td>0.53</td><td>0.98</td><td>0.69</td></tr><tr><td>E2F/DP</td><td><b>1.00</b></td><td>1.00</td><td>0.99</td><td>1.00</td></tr><tr><td>ERF</td><td><b>1.00</b></td><td>0.96</td><td>1.00</td><td>0.98</td></tr><tr><td>G2-like</td><td><b>0.99</b></td><td>0.81</td><td>0.99</t ...
#             <div style='margin-top: 20px; text-align: center;'>
#                 <button onclick="saveReport()" style='background-color: blue; color: white; padding: 10px 20px; border: none; cursor: pointer;'>Save Report</button>
#             </div>
#             <script>
#                 function saveReport() {
#                     var content = `<h3 style='display: flex; justify-content: space-between;'>                <span style='width: 100%;'>Overall Accuracy</span> <span style='padding: 0.3em;background-color: #1f77b4;color: #fff;font-size: 0.85em;'>kmer_size=5</span></h3>                <table style='width:100%; border-collapse: collapse; border: 1px solid black;'>                <tr><th style='text-align: left;'>Score</th><td>0.91</td></tr></table><h3>Accuracy per Gene Family</h3><div style=''>                <table style='width:calc(50% - 1em); float:left; border-collapse: collapse; border: 1px solid black; margin-left: 0.5em;'>                <tr><th>Gene Family</th><th>Accuracy</th><th>Precision</th><th>Recall</th><th>F1 Score</th></tr><tr><td>AP2</td><td><b>0.99</b></td><td>0.51</td><td>0.95</td><td>0.67</td></tr><tr><td>ARR-B</td><td><b>0.99</b></td><td>0.53</td><td>0.98</td><td>0.68</td></tr><tr><td>BBR-BPC</td><td><b>1.00</b></td><td>1.00</td><td>0.98</td><td>0.99</td></tr><tr><td>C2H2</td><td><b>0.99</b></td><td>1.00</td><td>0.84</td><td>0.91</td></tr><tr><td>CAMTA</td><td><b>1.00</b></td><td>1.00</td><td>1.00</td><td>1.00</td></tr><tr><td>CPP</td><td><b>1.00</b></td><td>1.00</td><td>0.97</td><td>0.99</td></tr><tr><td>Dof</td><td><b>1.00</b></td><td>1.00</td><td>1.00</td><td>1.00</td></tr><tr><td>EIL</td><td><b>1.00</b></td><td>1.00</td><td>0.98</td><td>0.99</td></tr><tr><td>FAR1</td><td><b>1.00</b></td><td>0.97</td><td>0.94</td><td>0.95</td></tr><tr><td>GATA</td><td><b>1.00</b></td><td>1.00</td><td>0.98</td><td>0.99</td></tr><tr><td>GRF</td><td><b>1.00</b></td><td>1.00</td><td>1.00</td><td>1.00</td></tr><tr><td>HB-PHD</td><td><b>1.00</b></td><td>1.00</td><td>1.00</td><td>1.00</td></tr><tr><td>HD-ZIP</td><td><b>1.00</b></td><td>0.95</td><td>1.00</td><td>0.97</td></tr><tr><td>HSF</td><td><b>1.00</b></td><td>1.00</td><td>1.00</td><td>1.00</td></tr><tr><td>LFY</td><td><b>1.00</b></td><td>1.00</td><
